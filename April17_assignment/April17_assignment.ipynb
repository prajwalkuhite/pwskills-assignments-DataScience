# %% [markdown]
# # Q1. What is Gradient Boosting Regression?

# %% [markdown]
# Gradient Boosting Regression is a machine learning technique used for regression problems. It combines multiple weak models, usually decision trees, to create a strong predictive model.
#
# The algorithm works in an iterative manner. It starts with an initial weak model and trains it on the data. Then, subsequent models are built to correct the errors made by the previous models.
#
# At each iteration, the algorithm focuses on the instances that were poorly predicted. It calculates the difference between the actual target values and the predicted values from the previous model. These differences, called residuals or errors, become the targets for the next model.
#
# The new model is trained to minimize the residuals by fitting the data to the residual values. This process is repeated, with each new model attempting to correct the errors of the previous models.
#
# The predictions from all the models are combined to make the final prediction. The models are added sequentially, and their predictions are summed up to yield the final prediction.
#
# Gradient Boosting uses a gradient descent optimization algorithm to minimize the loss function associated with the residuals. This algorithm finds the optimal weights for each weak model to minimize the overall loss.
#
# ![image.png](attachment:97a16d29-0629-4ba8-968c-5382caf9b716.png)

# %% [markdown]
# # Q2. Implement a simple gradient boosting algorithm from scratch using Python and NumPy. Use a simple regression problem as an example and train the model on a small dataset. Evaluate the model's performance using metrics such as mean squared error and R-squared.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Dataset making
from sklearn.datasets import make_regression
X,y = make_regression(n_samples=500,n_features=1,n_informative=1,random_state=42,noise=15)

# %%
df = pd.DataFrame(data=X, columns=['X'])
df['y'] = y

# %%
df.head()
# Out:
#           X           y
# 0 -0.808298  -45.000948
# 1  0.096996    3.779291
# 2  0.473238   25.307011
# 3 -1.478522 -106.350371
# 4 -0.385314  -22.880355

# %%
## BAse Model 

df['pred1'] = np.mean(df['y'])

# %%
## Residuals of Base Model M1
df['R1'] = df['y'] - df['pred1']

# %%
df.head()
# Out:
#           X           y     pred1          R1
# 0 -0.808298  -45.000948 -0.151737  -44.849211
# 1  0.096996    3.779291 -0.151737    3.931028
# 2  0.473238   25.307011 -0.151737   25.458748
# 3 -1.478522 -106.350371 -0.151737 -106.198633
# 4 -0.385314  -22.880355 -0.151737  -22.728617

# %%
plt.scatter(df['X'],df['y'])
plt.plot(df['X'],df['pred1'],color='red')

# %%
## Now making Decision tree models M2,M3,M4....
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # Q4. What is a weak learner in Gradient Boosting?

# %% [markdown]
# In Gradient Boosting, a weak learner is a machine learning algorithm that performs only slightly better than random guessing, but is still able to learn from the training data. The concept of a weak learner in Gradient Boosting algorithm, combines many weak learners to create a strong learner.
#
# In Gradient Boosting, each weak learner is typically a decision tree with a shallow depth, often referred to as a decision stump. During training, the algorithm fits the weak learner to the data, and then adjusts the weights of the training examples to focus on the examples that were poorly predicted by the previous weak learner. The algorithm then adds the new weak learner to the ensemble, and repeats this process many times to gradually improve the model's accuracy.
#
# The strength of the Gradient Boosting algorithm lies in its ability to combine many weak learners to create a strong learner. By adding many weak learners and focusing on the examples that are difficult to predict, the algorithm is able to learn complex relationships in the data and create a highly accurate model.

# %% [markdown]
# # Q5. What is the intuition behind the Gradient Boosting algorithm?

# %% [markdown]
# The intuition behind the Gradient Boosting algorithm is to iteratively improve the accuracy of a model by combining many weak learners to create a strong learner.
#
# The algorithm starts by fitting a weak learner to the training data. This initial model may not be very accurate, but it provides a starting point for the algorithm to build on. The algorithm then evaluates the errors made by this model, and focuses on the examples that were poorly predicted. The next weak learner is then trained to focus on these difficult examples, in an attempt to correct the errors made by the previous model.
#
# This process of adding a new weak learner and adjusting the weights of the examples is repeated many times, with each new weak learner improving on the errors made by the previous model. The final model is then created by combining all of the weak learners into a single ensemble model.
#
# The key idea behind Gradient Boosting is that each weak learner focuses on the examples that are difficult to predict, and by combining many of these weak learners, the algorithm is able to learn complex relationships in the data and create a highly accurate model. The "gradient" in the name comes from the fact that the algorithm uses the gradient of the loss function to determine how to adjust the weights of the training examples at each step, in order to focus on the examples that are difficult to predict.

# %% [markdown]
# # Q6. How does Gradient Boosting algorithm build an ensemble of weak learners?

# %% [markdown]
# Here is a step-by-step explanation of how this process occurs:
#
# 1. `Initialize the ensemble`: The process starts by initializing the ensemble with a weak learner, usually a simple model like a decision tree with limited depth. This weak learner is often referred to as the "base model" or "base learner."
#
# 2. `Make initial predictions`: The base model is used to make predictions on the training data. These initial predictions may not be accurate, and there will be residual errors (differences between the actual target values and the predictions).
#
# 3. `Compute the residuals`: The algorithm calculates the residuals by taking the difference between the actual target values and the predictions made by the current ensemble.
#
# 4. `Train a new weak learner`: A new weak learner, often referred to as the "boosting model," is trained on the residuals. The goal of this model is to learn and capture the patterns in the residuals that were not captured by the previous weak learners. The boosting model is trained to minimize the loss function on the residuals.
#
# 5. `Update the ensemble`: The predictions of the boosting model are added to the predictions of the previous weak learners in the ensemble. The ensemble now includes the predictions of all the weak learners constructed so far.
#
# 6. `Repeat the process`: Steps 3-5 are repeated iteratively. In each iteration, the algorithm focuses on the residuals (errors) of the current ensemble and trains a new weak learner to correct those errors. The predictions of the new weak learner are added to the ensemble, and the process continues.
#
# 7. `Determine the final prediction`: The final prediction of the Gradient Boosting ensemble is obtained by aggregating the predictions of all the weak learners. The specific aggregation method depends on the problem type (e.g., regression or classification) and the implementation used. Common approaches include weighted averaging or using a weighted voting scheme.

# %% [markdown]
# # Q7. What are the steps involved in constructing the mathematical intuition of Gradient Boosting algorithm?

# %% [markdown]
# Here are the main steps involved:
#
# 1. `Define a loss function`: The first step in constructing the mathematical intuition of Gradient Boosting is to define a loss function that measures the difference between the predicted values and the actual target values. The choice of loss function depends on the problem type, such as regression or classification.
#
# 2. `Initialize the model`: The second step is to initialize the model with a simple base learner. This base learner can be any weak learning algorithm such as decision tree or regression model.
#
# 3. `Compute the residual errors`: The next step is to compute the residual errors, which represent the difference between the actual target values and the predictions made by the current model. These residual errors will be the targets for the next model.
#
# 4. `Train the next model`: The next step is to train the next model, which should be better than the previous one. The new model is trained to minimize the loss function on the residual errors. This is done by fitting the new model to the residual errors.
#
# 5. `Combine the models`: The predictions of the new model are then added to the predictions of the previous model, thus creating an ensemble model.
#
# 6. `Iterate the process`: Steps 3-5 are repeated iteratively until the model's performance converges or a predefined stopping criterion is met.
#
# 7. `Make final predictions`: The final step is to make the final predictions by aggregating the predictions of all the models in the ensemble.
#
# The Gradient Boosting algorithm involves iteratively improving a model's predictive performance by minimizing the loss function on the residual errors. This is done by adding new models to the ensemble and training them to correct the errors of the previous models. By iteratively adding better models to the ensemble, the algorithm creates a highly accurate predictive model.
