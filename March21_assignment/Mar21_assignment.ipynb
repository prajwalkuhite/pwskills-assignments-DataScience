# %% [markdown]
# # Q1. What is the difference between Ordinal Encoding and Label Encoding? Provide an example of when you might choose one over the other.

# %% [markdown]
# ### Ordinal Encoder:
# In ordinal encoder technique we have advantage to give a specific rank to our categorical data.
# So when we transform the feature into numerical feature then the output should will be our own defined rank number.
#
# ### Label Encoder:
# In label encoder technique the rank is not user defined , here the rank was automatically has been given to categorical data according to alphabetical order.
#
# #### So basically when we want the rank should be given by us then we use ordinal encoder otherwise Label encoder.
# #### Generally Label encoder was used for target variable and ordinal is for normal categorical feature.

# %% [markdown]
# # Q2. Explain how Target Guided Ordinal Encoding works and provide an example of when you might use it in a machine learning project.

# %% [markdown]
# #### Target Guided Ordinal Encoding
# It is a technique used to encode categorical variables based on their relationship with the target variable. This encoding technique is useful when we have a categorical variable with a large number of unique categories, and we want to use this variable as a feature in our machine learning model.
#
# In Target Guided Ordinal Encoding, we replace each category in the categorical variable with a numerical value based on the mean or median of the target variable for that category. This creates a monotonic relationship between the categorical variable and the target variable, which can improve the predictive power of our model.
#
# ##### we use this technique whwn we need a relationship between the categorical variable and the target variable.

# %% [markdown]
# # Q3. Define covariance and explain why it is important in statistical analysis. How is covariance calculated?

# %% [markdown]
# #### Covariance is a measure of the relationship between two random variables and to what extent, they change together. Or we can say, in other words, it defines the changes between the two variables, such that change in one variable is equal to change in another variable. This is the property of a function of maintaining its form when the variables are linearly transformed. Covariance is measured in units, which are calculated by multiplying the units of the two variables.
#
# #### When two variables move in the same direction, it results in a positive covariance.
#
# #### When two variables move in the opposite direction, it results in a negative covariance.
#
# ![download.png](attachment:5935e5cf-f789-4476-9190-25bddc2154ae.png)
#
# #### Importance:
# Covariance is a statistical term that refers to a systematic relationship between two random variables in which a change in the other reflects a change in one variable.
#
# The covariance value can range from -∞ to +∞, with a negative value indicating a negative relationship and a positive value indicating a positive relationship.
#
# The greater this number, the more reliant the relationship. Positive covariance denotes a direct relationship and is represented by a positive number.
#
# A negative number, on the other hand, denotes negative covariance, which indicates an inverse relationship between the two variables. Covariance is great for defining the type of relationship, but it's terrible for interpreting the magnitude.

# %% [markdown]
# # Q4. For a dataset with the following categorical variables: Color (red, green, blue), Size (small, medium, large), and Material (wood, metal, plastic), perform label encoding using Python's scikit-learn library. Show your code and explain the output.

# %%
# Firstly i created a dataframe
import pandas as pd

df = pd.DataFrame({'Color': ('red', 'green', 'blue'), 
                   'Size': ('small', 'medium', 'large'),
                   'Material': ('wood', 'metal', 'plastic')

})

# %%
df
# Out:
#    Color    Size Material
# 0    red   small     wood
# 1  green  medium    metal
# 2   blue   large  plastic

# %%
# Now i was going to encode the categorical feature using Label Encoder

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# %%
# Encoding Color feature
df_color = encoder.fit_transform(df['Color'])
df['encoded_color'] = df_color

# %%
# Encoding Size feature
df_size = encoder.fit_transform(df['Size'])
df['encoded_size'] = df_size

# %%
# Encoding Material feature
df_material = encoder.fit_transform(df['Material'])
df['encoded_material'] = df_material

# %% [markdown]
# ### Output Explained:
# So here all the columns has been successfully encoded using Label Encoder.
#
# Here the Output rank of a particular column has been generated automatically by python without user defined ranking.
#
# It Ranks according to alphabetical order of categorical values inside a particular categorical feature.

# %%
df
# Out:
#      Size Material  encode_color  encoded_color  encoded_size  \
# 0   small     wood             2              2             2
# 1  medium    metal             1              1             1
# 2   large  plastic             0              0             0
#
#    encoded_material
# 0                 2
# 1                 0
# 2                 1

# %% [markdown]
# # Q5. Calculate the covariance matrix for the following variables in a dataset: Age, Income, and Education level. Interpret the results.

# %%
# Creating a dataser
df5 = pd.DataFrame({'Age':[22,23,30],
                    'Income':[5000,10000,50000],
                    'Education_level':['Bsc','Msc','PHd']
})

# %%
df5
# Out:
#    Age  Income Education_level
# 0   22    5000             Bsc
# 1   23   10000             Msc
# 2   30   50000             PHd

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder(categories=[['Bsc','Msc','PHd']])
encoded_Edu = encoder.fit_transform(df5[['Education_level']])
df5['Edu_lev_Encode'] = encoded_Edu

# %%
df5.drop('Education_level',inplace=True,axis=1)

# %%
df5
# Out:
#    Age  Income  Edu_lev_Encode
# 0   22    5000             0.0
# 1   23   10000             1.0
# 2   30   50000             2.0

# %%
df5.cov()
# Out:
#                      Age        Income  Edu_lev_Encode
# Age                 19.0  1.075000e+05             4.0
# Income          107500.0  6.083333e+08         22500.0
# Edu_lev_Encode       4.0  2.250000e+04             1.0

# %% [markdown]
# # Q6. You are working on a machine learning project with a dataset containing several categorical variables, including "Gender" (Male/Female), "Education Level" (High School/Bachelor's/Master's/PhD), and "Employment Status" (Unemployed/Part-Time/Full-Time). Which encoding method would you use for each variable, and why?

# %% [markdown]
# #### 1. "Gender" (Male/Female):
# I go for nominal encoding in which ONE HOT ENCODER technique i used because there was not a rank here in the categorical unique data.
#
# #### 2. "Education Level" (High School/Bachelor's/Master's/PhD):
# I go for ordinal encoding in which ordinal encder technique i used because there was a rank here in the categorical unique data, here first i have to define rank.
#
# Like for High School ---- 1 ,
#  Bachelor's ---- 2 ,
#  Master's ---- 3 ,
#  PhD ---- 4 ,
#
# #### 3. "Employment Status" (Unemployed/Part-Time/Full-Time):
# I go for ordinal encoding in which ordinal encder technique i used because there was a rank here in the categorical unique data, here first i have to define rank.
#
# like for Unemployed --- 1 ,
# Part-Time --- 2 ,
# Full-Time --- 3

# %% [markdown]
# # Q7. You are analyzing a dataset with two continuous variables, "Temperature" and "Humidity", and two categorical variables, "Weather Condition" (Sunny/Cloudy/Rainy) and "Wind Direction" (North/South/ East/West). Calculate the covariance between each pair of variables and interpret the results.

# %%
import numpy as np
import pandas as pd

# Set seed for reproducibility
np.random.seed(321)

# Generate data
n = 1000
temp = np.random.normal(25, 5, n)
humidity = np.random.normal(60, 10, n)
weather_condition = np.random.choice(['Sunny', 'Cloudy', 'Rainy'], size=n)
wind_direction = np.random.choice(['North', 'South', 'East', 'West'], size=n)

# Create dataframe
df = pd.DataFrame({
    'Temperature': temp, 
    'Humidity': humidity, 
    'Weather Condition': weather_condition, 
    'Wind Direction': wind_direction
})

# Show first few rows
df.head()
# Out:
#    Temperature   Humidity Weather Condition Wind Direction
# 0    25.862597  50.526311             Sunny          South
# 1    33.177413  55.809608             Sunny          South
# 2    25.186682  70.091030             Sunny           West
# 3    20.579252  68.981094             Sunny          South
# 4    19.284039  78.624127             Rainy           East

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.cov(numeric_only=True)
# Out:
#              Temperature    Humidity
# Temperature    25.165416    1.610779
# Humidity        1.610779  105.612893
