# %% [markdown]
# # Q1. What is data encoding? How is it useful in data science?

# %% [markdown]
# Data Encoding is a technique of converting categorical variables into numerical values so that it could be easily fitted to a machine learning model.
#
# The ML model only understand the numerical data thata why it is necessary to convert our categorical feature into numerical feature.
#
# Data encoding is very useful to train our model properly, this results in increase the testing or predictions of model more accurately.
#
# Machine learning models can only work with numerical values. For this reason, it is necessary to transform the categorical values of the relevant features into numerical ones. This process is also called feature encoding.

# %% [markdown]
# # Q2. What is nominal encoding? Provide an example of how you would use it in a real-world scenario.

# %% [markdown]
# ##### Nominal Encoding
# Nominal encoding is the process of converting categorical feature into numerical feature.
#
# When we have a feature where variables are just names and there is no order or rank to this variable's feature.
#
# For example: City of person lives in, Gender of person, Marital Status, etc…
#
# In the above example, We do not have any order or rank, or sequence. All the variables in the respective feature are equal. We can't give them any orders or ranks. Those features are called Nominal features.
#
# ##### Real-world Scenario :
# we can achieve the nominal encoding by using ONE HOT ENCODING (OHE)
#
# In OHE : one-hot encoding is a process of converting categorical data into binary format so that the data with converted categorical values can be provided to the models to give and improve the predictions.
#
# Example : Suppose we have Animal feature in whic nominal data conatain, so by using OHE we can convert this nominal category data into numerical binary (0,1) data.
#
# ![image.png](attachment:979afc77-42cb-46a1-9985-430ca169be16.png)

# %% [markdown]
# # Q3. In what situations is nominal encoding preferred over one-hot encoding? Provide a practical example.

# %% [markdown]
# ### I think the question is wrong
#
# The One Hot Encoding is one of the technique of Nominal Encoding for Data Encoding.
#
# When the in categorical feature nominal data contain we use One Hot Encoding technique.
#
# Otherwise:
#
# if the Categorical feature contain ordinal data we use ordinal encoding technique
#
# ![image.png](attachment:00245fa1-17a5-4826-bd9f-94a477f8a820.png)

# %% [markdown]
# # Q4. Suppose you have a dataset containing categorical data with 5 unique values. Which encoding technique would you use to transform this data into a format suitable for machine learning algorithms? Explain why you made this choice.

# %% [markdown]
# #### Firstly i analyse the data:
# 1. if the unique data seems like Nominal Data : Then i go for Nominal encoding in which ONE HOT ENCODING technique i use.
#
# That is if there s not a specific rank in unique data then i definetely use ONE HOT ENCODER technique.
#
# ### or
#
# 2. if the unique data seems like Ordinal Data : Then i go for Ordinal encoding in which Ordinal Encoder technique i use.
#
# That is if there is a specific rank in unique data then i definetely use ORDINAL ENCODER technique.

# %% [markdown]
# # Q5. In a machine learning project, you have a dataset with 1000 rows and 5 columns. Two of the columns are categorical, and the remaining three columns are numerical. If you were to use nominal encoding to transform the categorical data, how many new columns would be created? Show your calculations.

# %% [markdown]
# #### 1. So firstly i calculate the unique values in both the categorical feature.
#
# #### 2. Suppose 1st feature has 5 unique values and 2nd has 3 unique values then for each unique value separate column has been created using Nominal/OHE Encoding Technique.
#
# #### Calculation:
# For 1st and 2nd Categorical column, 5 and 3 unique values are there respectively.
#
# Therefore,  5 + 3 = 8
#
# 8 new columns has been created

# %% [markdown]
# # Q6. You are working with a dataset containing information about different types of animals, including their species, habitat, and diet. Which encoding technique would you use to transform the categorical data into a format suitable for machine learning algorithms? Justify your answer.

# %% [markdown]
# 1. So basically the categorical data species , habitat and diet have no particular ranking so we use Nominal encoding.
#
# 2. If the categorical data has no natural order or ranking, then one-hot encoding can be used.
#
# 3. Hence One-Hot Encoding would be preffered in above case.

# %% [markdown]
# # Q7.You are working on a project that involves predicting customer churn for a telecommunications company. You have a dataset with 5 features, including the customer's gender, age, contract type, monthly charges, and tenure. Which encoding technique(s) would you use to transform the categorical data into numerical data? Provide a step-by-step explanation of how you would implement the encoding.

# %% [markdown]
# ### So here we have 5 columns:
# 1. Gender --- Categorical Data
# 2. Age --- Numerical Data
# 3. Contract type --- Categorical Data
# 4. Monthly_Charges --- Numerical Data
# 5. Tenure --- Numerical Data
#
# #### Now, I have to transform the categorical column into numerical data.
#
# ##### 1. I use here Nominal /One Hot Encoding technique for Gender column because there was not a specific rankling here
#
# ##### 2. for Contract_type column i use Ordinal Encoding because there must be a rank in their unique values
#
# #### Steps for Gender column -- using ONE HOT ENCODER:
# 1. From Library Sklearn.preprocessing import OneHotEncoder
# 2. Make a instance of OneHotEncoder
# 3. Fit the gender column in that instance
# 4. Transform this data and we get our numerical data.
# 5. Then i Create a new column in Dataframe for this new_gender_numerical.
# 6. Lastly I concat this with my original Dataset
# 7. Afterward i also need to remove gender column permanently because it is categorical and ML model not understand this.
#
# #### Steps for Contract_type column -- using Ordinal ENCODER:
# 1. From Library Sklearn.preprocessing import OrdinalEncoder
# 2. Make a instance of OrdinalEncoder
# 3. Fit the contract_type column in that instance
# 4. Transform this data and we get our numerical data.
# 5. Then i Create a new column in Dataframe for this new_contract_type_numerical.
# 6. Lastly I concat this with my original Dataset
# 7. Afterward i also need to remove contract_type column permanently because it is categorical and ML model not understand this.
#
# #### Hence by this i would solve this question.
